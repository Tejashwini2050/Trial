# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import KFold

from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
# !mkdir main
# Out:
# A subdirectory or file main already exists.

# %%
pwd
# Out:
# 'C:\\Users\\ADMIN\\Desktop\\STROKE'

# %%
#importing dataset
data = tf.keras.utils.image_dataset_from_directory(
    "main",
    labels='inferred',label_mode='categorical',image_size=(256,256),
    batch_size=1
)
# Out:
# Found 3770 files belonging to 2 classes.

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal")
])
#random flip augmentation is applied

# %%
#creating the augmented dataset
aug_ds = data.map(
  lambda x, y: (data_augmentation(x, training=True), y))

# %%
class_names = data.class_names
class_names #the image_data_from_directory function choses the folder name as classes
# Out:
# ['noStroke_data', 'stroke_data']

# %%
dataX = []
dataY = []
for i in data.as_numpy_iterator():
  dataX.append(i[0])
  dataY.append(i[1])


for i in aug_ds.as_numpy_iterator():
  if i[1][0][1] == 1.:
    dataX.append(i[0])
    dataY.append(i[1])
dataX = np.array(dataX)
dataY = np.array(dataY)
dataX = np.reshape(dataX,(dataX.shape[0],256,256,3))
dataY = np.reshape(dataY,(dataY.shape[0],2))
dataX.shape, dataY.shape #87 images in total along with labels
# Out:
# ((5029, 256, 256, 3), (5029, 2))

# %%
dataY[0]
# Out:
# array([1., 0.], dtype=float32)

# %%
def define_model():
  
  model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255), #normalize the data
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(192, activation='relu'),
  tf.keras.layers.Dense(2,activation='sigmoid')
  ])

  opt = tf.keras.optimizers.SGD(learning_rate=0.01)
  model.compile(optimizer=opt, 
                loss=tf.keras.losses.BinaryCrossentropy(), 
                metrics=['accuracy',
                tf.keras.metrics.AUC(name='AUC'),
                tf.keras.metrics.Precision(name='Precision'),
                tf.keras.metrics.Recall(name="Recall")])
  return model

# %%
def train_and_evaluate_model(dataX, dataY, n_folds=3):
  scores, histories = list(), list()
  models = []
  # prepare cross validation
  kfold = KFold(n_folds, shuffle=True, random_state=1)
  # enumerate splits
  for train_ix, test_ix in kfold.split(dataX):
    # define model
    model = define_model()
    
    # select rows for train and test
    trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
    # fit model
    history = model.fit(trainX, trainY, epochs=10, batch_size=1, validation_data=(testX, testY), verbose=1)
    # evaluate model
    _, acc, _ , _, _= model.evaluate(testX, testY, verbose=1)
    print('> %.3f' % (acc * 100.0))
    # stores scores
    scores.append(acc)
    models.append(model)
    histories.append(history)
  model.summary()

  return scores, histories, models

# %%
def summarize_diagnostics(histories):
  plt.figure(figsize=(10,10))
  colors = ['r','y','blue']
  for i in range(len(histories)):
    # plot loss
    
    pyplot.subplot(2, 1, 1)
    pyplot.title('Cross Entropy Loss')
    pyplot.plot(histories[i].history['loss'], color=colors[i], label='train')
    pyplot.plot(histories[i].history['val_loss'], color=colors[i], label='test',ls='dashed')
    # plot accuracy
    pyplot.subplot(2, 1, 2)
    pyplot.title('Classification Accuracy')
    pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
    pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
  
  pyplot.show()


# summarize model performance
def summarize_performance(scores):
  # print summary
  print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
  # box and whisker plots of results
  pyplot.boxplot(scores)
  pyplot.show()

# %%
scores, histories, models = train_and_evaluate_model(dataX,dataY)
# Out:
# Epoch 1/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 143s 42ms/step - AUC: 0.6971 - Precision: 0.6567 - Recall: 0.6592 - accuracy: 0.6575 - loss: 0.6337 - val_AUC: 0.8483 - val_Precision: 0.7474 - val_Recall: 0.8008 - val_accuracy: 0.7674 - val_loss: 0.5551
# Epoch 2/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.8729 - Precision: 0.8016 - Recall: 0.7981 - accuracy: 0.8039 - loss: 0.4547 - val_AUC: 0.8829 - val_Precision: 0.8065 - val_Recall: 0.7680 - val_accuracy: 0.7883 - val_loss: 0.4177
# Epoch 3/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.9072 - Precision: 0.8373 - Recall: 0.8356 - accuracy: 0.8369 - loss: 0.3871 - val_AUC: 0.9040 - val_Precision: 0.8210 - val_Recall: 0.8235 - val_accuracy: 0.8217 - val_loss: 0.4013
# Epoch 4/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.9365 - Precision: 0.8646 - Recall: 0.8644 - accuracy: 0.8649 - loss: 0.3334 - val_AUC: 0.9011 - val_Precision: 0.8080 - val_Recall: 0.8229 - val_accuracy: 0.8140 - val_loss: 0.4096
# Epoch 5/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.9684 - Precision: 0.9128 - Recall: 0.9119 - accuracy: 0.9161 - loss: 0.2375 - val_AUC: 0.8993 - val_Precision: 0.8289 - val_Recall: 0.8265 - val_accuracy: 0.8283 - val_loss: 0.4891
# Epoch 6/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.9621 - Precision: 0.8998 - Recall: 0.9004 - accuracy: 0.9006 - loss: 0.2543 - val_AUC: 0.9664 - val_Precision: 0.9174 - val_Recall: 0.9141 - val_accuracy: 0.9159 - val_loss: 0.2552
# Epoch 7/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.9921 - Precision: 0.9609 - Recall: 0.9619 - accuracy: 0.9612 - loss: 0.1105 - val_AUC: 0.7687 - val_Precision: 0.7195 - val_Recall: 0.7114 - val_accuracy: 0.7191 - val_loss: 1.0476
# Epoch 8/10
# 3352/3352 ━━━━━━━━━━━━━━━━━━━━ 142s 42ms/step - AUC: 0.9632 - Precision: 0.9118 - Recall: 0.9158 - accuracy: 0.9131 - loss: 0.2470 - val_AUC: 0.9294 - val_Precision: 0.8623 - val_Recall: 0.8551 - val_accuracy: 0.8611 - val_loss: 0.3863
# Epoch 9/10
10
# 3353/3353 ━━━━━━━━━━━━━━━━━━━━ 143s 43ms/step - AUC: 0.9870 - Precision: 0.9494 - Recall: 0.9518 - accuracy: 0.9515 - loss: 0.1446 - val_AUC: 0.8314 - val_Precision: 0.7393 - val_Recall: 0.7309 - val_accuracy: 0.7381 - val_loss: 0.5019
# Epoch 10/10
# 3353/3353 ━━━━━━━━━━━━━━━━━━━━ 146s 44ms/step - AUC: 0.9589 - Precision: 0.9066 - Recall: 0.9048 - accuracy: 0.9052 - loss: 0.2477 - val_AUC: 0.9422 - val_Precision: 0.8729 - val_Recall: 0.8687 - val_accuracy: 0.8729 - val_loss: 0.3575
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - AUC: 0.9461 - Precision: 0.8882 - Recall: 0.8839 - accuracy: 0.8886 - loss: 0.3370
# > 87.291
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (1, 256, 256, 3)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (1, 254, 254, 64)      │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (1, 127, 127, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (1, 125, 125, 64)      │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (1, 62, 62, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (1, 246016)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (1, 192)               │    47,235,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (1, 2)                 │           386 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47,274,372 (180.34 MB)
#  Trainable params: 47,274,370 (180.34 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
#metrics for the folds
for i in range(len(histories)):
    p = np.mean(histories[i].history['val_Precision'])
    r = np.mean(histories[i].history['val_Recall'])
    auc = np.mean(histories[i].history['val_AUC'])
    acc = np.mean(histories[i].history['val_accuracy'])
    f1 = (2*(p*r))/(p+r)
    print("Fold "+ str(i+1))
    print(f'Accuracy: {acc*100:.3f}')
    print(f'f1 score: {f1:.3f}')
    print(f'Precision: {p:.3f}')
    print(f'Recall: {r:.3f}')
    print(f'AUC: {auc:.3f}')
# Out:
# Fold 1
# Accuracy: 83.894
# f1 score: 0.839
# Precision: 0.838
# Recall: 0.840
# AUC: 0.904
# Fold 2
# Accuracy: 86.402
# f1 score: 0.865
# Precision: 0.863
# Recall: 0.867
# AUC: 0.922
# Fold 3
# Accuracy: 84.905
# f1 score: 0.848
# Precision: 0.849
# Recall: 0.848
# AUC: 0.916

# %%
avg_loss = np.add(np.add(histories[0].history['loss'], histories[2].history['loss']), histories[1].history['loss'])/3
avg_val_loss = np.add(np.add(histories[0].history['val_loss'], histories[2].history['val_loss']), histories[1].history['val_loss'])/3
#plot of train vs test loss
plt.plot(avg_loss[:],c='r')
plt.plot(avg_val_loss[:],c='b')
plt.xlabel("Epoches")
plt.ylabel("Loss")
plt.legend(["Training Loss","Test Loss"])
plt.show()

# %%
avg_loss = []
avg_val_loss = []
#loss of the different folds
for h in histories:
  avg_loss.append(np.average(h.history['loss']))
  avg_val_loss.append(np.average(h.history['val_loss']))
plt.plot(avg_loss)
plt.plot(avg_val_loss,ls='dotted')
default = range(len(avg_loss))
plt.xlabel('Model No')
plt.xticks(default,[1,2,3])                            
plt.ylabel("Average Loss")
plt.legend(["Train","Test"])
plt.show()

# %%
summarize_diagnostics(histories)
summarize_performance(scores)
# Out:
# Accuracy: mean=92.543 std=3.776, n=3

# %%
import pickle

# %%
pickle.dump(models, open('model_dump_deep.pkl', 'wb'))

# %%
import pickle
pickle.dump(models, open('model_dump_deep_deep_learning.pkl', 'wb'))
